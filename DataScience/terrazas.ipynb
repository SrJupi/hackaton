# %%
import pandas as pd

# %%
df_ter = pd.read_csv('terrasses_nom_local.csv')

# %%
df_ter.head(5)
# Out:
#    Unnamed: 0  CODI_BARRI                       NOM_BARRI  \
# 0           0           9  la Nova Esquerra de l'Eixample
# 1           1           9  la Nova Esquerra de l'Eixample
# 2           2           9  la Nova Esquerra de l'Eixample
# 3           3           9  la Nova Esquerra de l'Eixample
# 4           4           9  la Nova Esquerra de l'Eixample
#
#                EMPLACAMENT  SUPERFICIE_OCUPADA  TAULES  CADIRES    LATITUD  \
# 0         C. CALABRIA, 118                6.75     3.0     12.0  41.380772
# 1          C. PROVENÇA, 32                6.75     3.0     12.0  41.382319
# 2    C. COMTE BORRELL, 292                6.00     2.0      8.0  41.389437
# 3          C. ROSSELLO, 99                3.90     2.0      4.0  41.386384
# 4  C. CONSELL DE CENT, 140                2.40     2.0      4.0  41.381879
#
#    LONGITUD          Nom_Via Numero   nom_local
# 0  2.153789         CALABRIA    118         NaN
# 1  2.145211         PROVENÇA     32      varios
# ...

# %%
df_ter.columns = ['num_id', 'codBarrio', 'nomBarrio', 'direccion', 'area', 'mesas', 'sillas', 'lat', 'lon', 'nomVia', 'numVia', 'nomLocal']

# %%
df_ter.head(5)
# Out:
#    num_id    nomLocal           nomVia numVia                direccion  \
# 0       0         NaN         CALABRIA    118         C. CALABRIA, 118
# 1       1      varios         PROVENÇA     32          C. PROVENÇA, 32
# 2       2  BCN BRUNCH    COMTE BORRELL    292    C. COMTE BORRELL, 292
# 3       3         NaN         ROSSELLO     99          C. ROSSELLO, 99
# 4       4      varios  CONSELL DE CENT    140  C. CONSELL DE CENT, 140
#
#    codBarrio                       nomBarrio  area  mesas  sillas        lat  \
# 0          9  la Nova Esquerra de l'Eixample  6.75    3.0    12.0  41.380772
# 1          9  la Nova Esquerra de l'Eixample  6.75    3.0    12.0  41.382319
# 2          9  la Nova Esquerra de l'Eixample  6.00    2.0     8.0  41.389437
# 3          9  la Nova Esquerra de l'Eixample  3.90    2.0     4.0  41.386384
# 4          9  la Nova Esquerra de l'Eixample  2.40    2.0     4.0  41.381879
#
#         lon
# 0  2.153789
# 1  2.145211
# 2  2.146814
# 3  2.147948
# ...

# %%
df_ter = df_ter[['num_id', 'nomLocal', 'nomVia', 'numVia', 'direccion', 'codBarrio', 'nomBarrio', 'area', 'mesas', 'sillas', 'lat', 'lon']]

# %%
df_ter.head(5)
# Out:
#    num_id    nomLocal           nomVia numVia                direccion  \
# 0       0         NaN         CALABRIA    118         C. CALABRIA, 118
# 1       1      varios         PROVENÇA     32          C. PROVENÇA, 32
# 2       2  BCN BRUNCH    COMTE BORRELL    292    C. COMTE BORRELL, 292
# 3       3         NaN         ROSSELLO     99          C. ROSSELLO, 99
# 4       4      varios  CONSELL DE CENT    140  C. CONSELL DE CENT, 140
#
#    codBarrio                       nomBarrio  area  mesas  sillas        lat  \
# 0          9  la Nova Esquerra de l'Eixample  6.75    3.0    12.0  41.380772
# 1          9  la Nova Esquerra de l'Eixample  6.75    3.0    12.0  41.382319
# 2          9  la Nova Esquerra de l'Eixample  6.00    2.0     8.0  41.389437
# 3          9  la Nova Esquerra de l'Eixample  3.90    2.0     4.0  41.386384
# 4          9  la Nova Esquerra de l'Eixample  2.40    2.0     4.0  41.381879
#
#         lon
# 0  2.153789
# 1  2.145211
# 2  2.146814
# 3  2.147948
# ...

# %%
df_ter.to_csv('terrasses.csv', index = False)

# %%
len(df_ter['CODI_BARRI'].unique())
# Out:
# 69

# %%
df_ter[df_ter["codBarrio"] == 2]
# Out:
#       num_id    nomLocal       nomVia numVia           direccion  codBarrio  \
# 4066    4066      varios    SANT JUST      4    PL. SANT JUST, 4          2
# 4067    4067      varios  RIVADENEYRA      1   C. RIVADENEYRA, 1          2
# 4068    4068      varios       RAMBLA     74       C. RAMBLA, 74          2
# 4069    4069         NaN        REIAL     16       PL. REIAL, 16          2
# 4070    4070  CAFE BABEL  CORREU VELL     14  C. CORREU VELL, 14          2
# ...      ...         ...          ...    ...                 ...        ...
# 4272    4272      varios        REIAL      3        PL. REIAL, 3          2
# 4273    4273      varios        REIAL      7        PL. REIAL, 7          2
# 4274    4274      varios        REIAL     10       PL. REIAL, 10          2
# 4275    4275         NaN   . LAIETANA     19   VIA. LAIETANA, 19          2
# 4276    4276         NaN          BOT  23-25       C. BOT, 23-25          2
#
# ...
