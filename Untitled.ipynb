# %%
import pandas as pd

# %%
import numpy as np

# %%
df_loc = pd.read_csv('2019_censcomercialbcn_detall.csv')
df_ter = pd.read_csv('2021_1s_data_set_opendata_terrasses.csv')
# Out:
# c:\users\lucas\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (35,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_loc.rename(columns = {'Latitud':'LATITUD', 'Longitud':'LONGITUD'}, inplace = True)

# %%
df_loc.columns
# Out:
# Index(['ID_Bcn_2019', 'ID_Bcn_2016', 'Codi_Principal_Activitat',
#        'Nom_Principal_Activitat', 'Codi_Sector_Activitat',
#        'Nom_Sector_Activitat', 'Codi_Grup_Activitat', 'Nom_Grup_Activitat',
#        'Codi_Activitat_2019', 'Nom_Activitat', 'Codi_Activitat_2016',
#        'Nom_Local', 'SN_Oci_Nocturn', 'SN_Coworking', 'SN_Servei_Degustacio',
#        'SN_Obert24h', 'SN_Mixtura', 'SN_Carrer', 'SN_Mercat', 'Nom_Mercat',
#        'SN_Galeria', 'Nom_Galeria', 'SN_CComercial', 'Nom_CComercial',
#        'SN_Eix', 'Nom_Eix', 'X_UTM_ETRS89', 'Y_UTM_ETRS89', 'LATITUD',
#        'LONGITUD', 'Direccio_Unica', 'Codi_Via', 'Nom_Via', 'Planta', 'Porta',
#        'Num_Policia_Inicial', 'Lletra_Inicial', 'Num_Policia_Final',
#        'Lletra_Final', 'Solar', 'Codi_Parcela', 'Codi_Illa', 'Seccio_Censal',
#        'Codi_Barri', 'Nom_Barri', 'Codi_Districte', 'Nom_Districte',
#        'Referencia_cadastral', 'Data_Revisio'],
#       dtype='object')

# %%
left_merged = pd.merge(df_ter, df_loc, how="left", on=["LATITUD", "LONGITUD"])

# %%
filtered_df = left_merged[left_merged['ID_Bcn_2019'].notnull()]

# %%
pd.set_option('display.max_columns', 500)

# %%
df_loc.head(5)
# Out:
#    ID_Bcn_2019  ID_Bcn_2016  Codi_Principal_Activitat Nom_Principal_Activitat  \
# 0      1075454          NaN                         1                   Actiu
# 1      1075453          NaN                         1                   Actiu
# 2      1075451          NaN                         1                   Actiu
# 3      1075449          NaN                         1                   Actiu
# 4      1075448          NaN                         1                   Actiu
#
#    Codi_Sector_Activitat Nom_Sector_Activitat  Codi_Grup_Activitat  \
# 0                      2              Serveis                   16
# 1                      2              Serveis                   16
# 2                      2              Serveis                   16
# 3                      3               Altres                   17
# 4                      2              Serveis                   16
#
#   Nom_Grup_Activitat  Codi_Activitat_2019                      Nom_Activitat  \
# ...

# %%
df_ter.columns
# Out:
# Index(['DATA_EXPLO', 'OCUPACIO', 'CODI_DISTRICTE', 'NOM_DISTRICTE',
#        'CODI_BARRI', 'NOM_BARRI', 'EMPLACAMENT', 'SUPERFICIE_OCUPADA',
#        'TAULES', 'CADIRES', 'ORDENACIO', 'VIGENCIA', 'X_ETRS89', 'Y_ETRS89',
#        'LATITUD', 'LONGITUD'],
#       dtype='object')

# %%
df_ter.drop(columns=['DATA_EXPLO', 'OCUPACIO', 'CODI_DISTRICTE', 'NOM_DISTRICTE', 'ORDENACIO', 'VIGENCIA', 'X_ETRS89', 'Y_ETRS89'], inplace = True)

# %%
df_ter
# Out:
#       CODI_BARRI       NOM_BARRI              EMPLACAMENT  SUPERFICIE_OCUPADA  \
# 0              2  el Barri Gòtic            PL. REIAL, 10               36.00
# 1              2  el Barri Gòtic   PL. SANT FELIP NERI, 2               13.50
# 2              2  el Barri Gòtic  PL. PORTAL DE LA PAU, 4               54.00
# 3              2  el Barri Gòtic            PL. REIAL, 11               18.00
# 4              2  el Barri Gòtic          AV. CATEDRAL, 3               13.50
# ...          ...             ...                      ...                 ...
# 5715          68     el Poblenou            C. LLULL, 229                6.75
# 5716          68     el Poblenou            C. LLULL, 169                4.50
# 5717          68     el Poblenou       RBLA. POBLENOU, 56               22.50
# 5718          68     el Poblenou       RBLA. POBLENOU, 22               13.50
# 5719          68     el Poblenou       RBLA. POBLENOU, 55               13.50
#
# ...

# %%
df_ter.to_csv('terrasses.csv')

# %%
len(df_ter['CODI_BARRI'].unique())
# Out:
# 69
